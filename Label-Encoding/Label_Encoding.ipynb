# %%
import pandas as pd

# %%
df = pd.DataFrame({"object":["Yellow","Red","Cow","Dog","Shirt","T-Shirt"]})
df
# Out:
#     object
# 0   Yellow
# 1      Red
# 2      Cow
# 3      Dog
# 4    Shirt
# 5  T-Shirt

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df["en_object"] = le.fit_transform(df["object"])

# %%
df
# Out:
#     object  en_object
# 0   Yellow          5
# 1      Red          2
# 2      Cow          0
# 3      Dog          1
# 4    Shirt          3
# 5  T-Shirt          4

# %%
dataset = pd.read_csv("College_Admission.csv")
dataset.head()
# Out:
#    student_id  age  gender category          state preferred_stream  \
# 0      250.99   17   other  general         odisha       management
# 1      250.99   20   other      ews        gujarat      agriculture
# 2      250.99   19  female       sc  uttar pradesh         pharmacy
# 3      250.99   18    male      ews      meghalaya             arts
# 4      250.99   18    male       sc      rajasthan      engineering
#
#   entrance_exam  entrance_score  board_percentage  extracurricular_score  \
# 0           cet              30             95.58                      2
# 1          none               0             75.45                      2
# 2           cet             120             75.36                     10
# 3           cet             179             52.49                      2
# 4           jee             295             92.48                      7
#
#    admission_probability admission_status scholarship_eligibility
# ...

# %%
dataset["state"].unique()
# Out:
# array(['odisha', 'gujarat', 'uttar pradesh', 'meghalaya', 'rajasthan',
#        'himachal pradesh', 'nagaland', 'tamil nadu', 'telangana',
#        'jharkhand', 'goa', 'madhya pradesh', 'sikkim', 'maharashtra',
#        'assam', 'tripura', 'haryana', 'andhra pradesh', 'karnataka',
#        'kerala', 'arunachal pradesh', 'chhattisgarh', 'punjab', 'mizoram',
#        'bihar', 'manipur'], dtype=object)

# %%
la = LabelEncoder()
dataset["state"] = la.fit_transform(dataset["state"])

# %%
dataset
# Out:
#        student_id  age  gender category  state preferred_stream entrance_exam  \
# 0          250.99   17   other  general     18       management           cet
# 1          250.99   20   other      ews      6      agriculture          none
# 2          250.99   19  female       sc     25         pharmacy           cet
# 3          250.99   18    male      ews     15             arts           cet
# 4          250.99   18    male       sc     20      engineering           jee
# ...           ...  ...     ...      ...    ...              ...           ...
# 24995    24750.01   18  female      obc     25              law          none
# 24996    24750.01   20   other      ews      0       management          none
# 24997    24750.01   17    male      obc     14         pharmacy           cet
# 24998    24750.01   19    male      ews      0       management           cet
# 24999    24750.01   17  female      ews     24          nursing          none
#
# ...

# %%
dataset["state"].unique()
# Out:
# array([18,  6, 25, 15, 20,  8, 17, 22, 23,  9,  5, 12, 21, 13,  2, 24,  7,
#         0, 10, 11,  1,  4, 19, 16,  3, 14])

# %% [markdown]
# Label Encoding = Best for Ordinal data
#
# Can be used for nominal data ONLY with tree models
