# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("pokedex - Missing.csv")
dataset.head(3)
# Out:
#    Unnamed: 0  pokedex_number       name german_name        japanese_name  \
# 0           0             1.0  Bulbasaur     Bisasam  フシギダネ (Fushigidane)
# 1           1             2.0    Ivysaur   Bisaknosp   フシギソウ (Fushigisou)
# 2           2             3.0   Venusaur    Bisaflor  フシギバナ (Fushigibana)
#
#    generation  status       species  type_number type_1  ... against_ground  \
# 0         1.0  Normal  Seed Pokémon          2.0  Grass  ...            1.0
# 1         1.0  Normal  Seed Pokémon          2.0  Grass  ...            1.0
# 2         1.0  Normal  Seed Pokémon          2.0  Grass  ...            1.0
#
#    against_flying  against_psychic  against_bug against_rock against_ghost  \
# 0             2.0              2.0          1.0          1.0           1.0
# 1             2.0              2.0          1.0          1.0           1.0
# 2             2.0              2.0          1.0          1.0           1.0
#
#   against_dragon  against_dark  against_steel  against_fairy
# 0            1.0           1.0            1.0            0.5
# 1            1.0           1.0            1.0            0.5
# 2            1.0           1.0            1.0            0.5
#
# [3 rows x 51 columns]

# %%
dataset.shape
# Out:
# (1028, 51)

# %%
dataset.shape[0]
# Out:
# 1028

# %% [markdown]
# Finding missing values

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0            0
# pokedex_number       12
# name                 14
# german_name         102
# japanese_name       107
# generation           20
# status               11
# species              21
# type_number           8
# type_1                4
# type_2              487
# height_m              2
# weight_kg             3
# abilities_number      1
# ability_1            27
# ability_2           520
# ability_hidden      219
# total_points         16
# hp                   26
# attack                9
# defense               9
# sp_attack             9
# sp_defense            3
# speed                 2
# catch_rate          106
# base_friendship     106
# base_experience     105
# growth_rate          24
# egg_type_number      23
# egg_type_1            4
# egg_type_2          747
# percentage_male     237
# egg_cycles            2
# against_normal        1
# against_fire          1
# against_water         1
# against_electric      1
# against_grass         1
# against_ice           1
# against_fight         0
# against_poison        0
# against_ground        0
# against_flying        0
# against_psychic       0
# against_bug           0
# against_rock          0
# against_ghost         0
# against_dragon        0
# against_dark          0
# against_steel         0
# against_fairy         0
# dtype: int64

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# Unnamed: 0           0.000000
# pokedex_number       1.167315
# name                 1.361868
# german_name          9.922179
# japanese_name       10.408560
# generation           1.945525
# status               1.070039
# species              2.042802
# type_number          0.778210
# type_1               0.389105
# type_2              47.373541
# height_m             0.194553
# weight_kg            0.291829
# abilities_number     0.097276
# ability_1            2.626459
# ability_2           50.583658
# ability_hidden      21.303502
# total_points         1.556420
# hp                   2.529183
# attack               0.875486
# defense              0.875486
# sp_attack            0.875486
# sp_defense           0.291829
# speed                0.194553
# catch_rate          10.311284
# base_friendship     10.311284
# base_experience     10.214008
# growth_rate          2.334630
# egg_type_number      2.237354
# egg_type_1           0.389105
# egg_type_2          72.665370
# percentage_male     23.054475
# egg_cycles           0.194553
# against_normal       0.097276
# against_fire         0.097276
# against_water        0.097276
# against_electric     0.097276
# against_grass        0.097276
# against_ice          0.097276
# against_fight        0.000000
# against_poison       0.000000
# against_ground       0.000000
# against_flying       0.000000
# against_psychic      0.000000
# against_bug          0.000000
# against_rock         0.000000
# against_ghost        0.000000
# against_dragon       0.000000
# against_dark         0.000000
# against_steel        0.000000
# against_fairy        0.000000
# dtype: float64

# %%
dataset.notnull().sum().sum()
# Out:
# np.int64(49436)

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# np.float64(5.706874189364462)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %% [markdown]
# Deleting Missing Value

# %%
dataset.drop(columns=["egg_type_2"],inplace=True)

# %%
dataset
# Out:
#       Unnamed: 0  pokedex_number                         name german_name  \
# 0              0             1.0                    Bulbasaur     Bisasam
# 1              1             2.0                      Ivysaur   Bisaknosp
# 2              2             3.0                     Venusaur    Bisaflor
# 3              3             3.0                Mega Venusaur    Bisaflor
# 4              4             4.0                   Charmander    Glumanda
# ...          ...             ...                          ...         ...
# 1023        1023           888.0  Zacian Hero of Many Battles         NaN
# 1024        1024           889.0     Zamazenta Crowned Shield         NaN
# 1025        1025           889.0                          NaN         NaN
# 1026        1026           890.0                    Eternatus         NaN
# 1027        1027           890.0          Eternatus Eternamax         NaN
#
#             japanese_name  generation     status           species  \
# 0     フシギダネ (Fushigidane)         1.0     Normal      Seed Pokémon
# 1      フシギソウ (Fushigisou)         1.0     Normal      Seed Pokémon
# 2     フシギバナ (Fushigibana)         1.0     Normal      Seed Pokémon
# 3     フシギバナ (Fushigibana)         1.0     Normal      Seed Pokémon
# 4         ヒトカゲ (Hitokage)         1.0     Normal    Lizard Pokémon
# ...                   ...         ...        ...               ...
# 1023                  NaN         8.0  Legendary   Warrior Pokémon
# 1024                  NaN         8.0  Legendary   Warrior Pokémon
# 1025                  NaN         8.0  Legendary   Warrior Pokémon
# 1026                  NaN         8.0  Legendary  Gigantic Pokémon
# 1027                  NaN         8.0  Legendary  Gigantic Pokémon
#
#       type_number    type_1  ... against_ground  against_flying  \
# 0             2.0     Grass  ...            1.0             2.0
# 1             2.0     Grass  ...            1.0             2.0
# 2             2.0     Grass  ...            1.0             2.0
# 3             2.0     Grass  ...            1.0             2.0
# 4             1.0      Fire  ...            2.0             1.0
# ...           ...       ...  ...            ...             ...
# 1023          1.0     Fairy  ...            1.0             1.0
# 1024          2.0  Fighting  ...            2.0             1.0
# 1025          1.0  Fighting  ...            1.0             2.0
# 1026          2.0    Poison  ...            2.0             1.0
# 1027          2.0    Poison  ...            2.0             1.0
#
#       against_psychic  against_bug against_rock against_ghost against_dragon  \
# 0                 2.0         1.00         1.00           1.0            1.0
# 1                 2.0         1.00         1.00           1.0            1.0
# 2                 2.0         1.00         1.00           1.0            1.0
# 3                 2.0         1.00         1.00           1.0            1.0
# 4                 1.0         0.50         2.00           1.0            1.0
# ...               ...          ...          ...           ...            ...
# 1023              1.0         0.50         1.00           1.0            0.0
# 1024              1.0         0.25         0.25           1.0            0.5
# 1025              2.0         0.50         0.50           1.0            1.0
# 1026              2.0         0.50         1.00           1.0            2.0
# 1027              2.0         0.50         1.00           1.0            2.0
#
#       against_dark  against_steel  against_fairy
# 0              1.0            1.0            0.5
# 1              1.0            1.0            0.5
# 2              1.0            1.0            0.5
# 3              1.0            1.0            0.5
# 4              1.0            0.5            0.5
# ...            ...            ...            ...
# 1023           0.5            2.0            1.0
# 1024           0.5            0.5            1.0
# 1025           0.5            1.0            2.0
# 1026           1.0            1.0            1.0
# 1027           1.0            1.0            1.0
#
# [1028 rows x 50 columns]

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0            0
# pokedex_number       12
# name                 14
# german_name         102
# japanese_name       107
# generation           20
# status               11
# species              21
# type_number           8
# type_1                4
# type_2              487
# height_m              2
# weight_kg             3
# abilities_number      1
# ability_1            27
# ability_2           520
# ability_hidden      219
# total_points         16
# hp                   26
# attack                9
# defense               9
# sp_attack             9
# sp_defense            3
# speed                 2
# catch_rate          106
# base_friendship     106
# base_experience     105
# growth_rate          24
# egg_type_number      23
# egg_type_1            4
# percentage_male     237
# egg_cycles            2
# against_normal        1
# against_fire          1
# against_water         1
# against_electric      1
# against_grass         1
# against_ice           1
# against_fight         0
# against_poison        0
# against_ground        0
# against_flying        0
# against_psychic       0
# against_bug           0
# against_rock          0
# against_ghost         0
# against_dragon        0
# against_dark          0
# against_steel         0
# against_fairy         0
# dtype: int64

# %%
dataset.shape
# Out:
# (1028, 50)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#      Unnamed: 0  pokedex_number        name german_name        japanese_name  \
# 42           42            31.0   Nidoqueen   Nidoqueen    ニドクイン (Nidoqueen)
# 45           45            34.0    Nidoking    Nidoking     ニドキング (Nidoking)
# 52           52            39.0  Jigglypuff   Pummeluff          プリン (Purin)
# 53           53            40.0  Wigglytuff  Knuddeluff       プクリン (Pukurin)
# 59           59            46.0       Paras       Paras          パラス (Paras)
# ..          ...             ...         ...         ...                  ...
# 904         904           777.0  Togedemaru  Togedemaru   トゲデマル (Togedemaru)
# 906         906           779.0     Bruxish    Knirfish  ハギギシリ (Hagigishiri)
# 907         907           780.0      Drampa    Sen-Long     ジジーロン (Jijilong)
# 910         910           783.0    Hakamo-o     Mediras     ジャランゴ (Jyarango)
# 911         911           784.0     Kommo-o   Grandiras  ジャラランガ (Jyararanga)
#
#      generation  status              species  type_number    type_1  ...  \
# 42          1.0  Normal        Drill Pokémon          2.0    Poison  ...
# 45          1.0  Normal        Drill Pokémon          2.0    Poison  ...
# 52          1.0  Normal      Balloon Pokémon          2.0    Normal  ...
# 53          1.0  Normal      Balloon Pokémon          2.0    Normal  ...
# 59          1.0  Normal     Mushroom Pokémon          2.0       Bug  ...
# ..          ...     ...                  ...          ...       ...  ...
# 904         7.0  Normal    Roly-Poly Pokémon          2.0  Electric  ...
# 906         7.0  Normal  Gnash Teeth Pokémon          2.0     Water  ...
# 907         7.0  Normal       Placid Pokémon          2.0    Normal  ...
# 910         7.0  Normal        Scaly Pokémon          2.0    Dragon  ...
# 911         7.0  Normal        Scaly Pokémon          2.0    Dragon  ...
#
#     against_ground  against_flying  against_psychic  against_bug against_rock  \
# 42            2.00            1.00              2.0          0.5          0.5
# 45            2.00            1.00              2.0          0.5          0.5
# 52            1.00            1.00              1.0          0.5          1.0
# 53            1.00            1.00              1.0          0.5          1.0
# 59            0.25            4.00              1.0          2.0          2.0
# ..             ...             ...              ...          ...          ...
# 904           4.00            0.25              0.5          0.5          0.5
# 906           1.00            1.00              0.5          2.0          1.0
# 907           1.00            1.00              1.0          1.0          1.0
# 910           1.00            2.00              2.0          0.5          0.5
# 911           1.00            2.00              2.0          0.5          0.5
#
#     against_ghost against_dragon  against_dark  against_steel  against_fairy
# 42            1.0            1.0           1.0           1.00            0.5
# 45            1.0            1.0           1.0           1.00            0.5
# 52            0.0            0.0           0.5           2.00            1.0
# 53            0.0            0.0           0.5           2.00            1.0
# 59            1.0            1.0           1.0           1.00            1.0
# ..            ...            ...           ...            ...            ...
# 904           1.0            0.5           1.0           0.25            0.5
# 906           2.0            1.0           2.0           0.50            1.0
# 907           0.0            2.0           1.0           1.00            2.0
# 910           1.0            2.0           0.5           1.00            4.0
# 911           1.0            2.0           0.5           1.00            4.0
#
# [213 rows x 50 columns]

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0          0
# pokedex_number      0
# name                0
# german_name         0
# japanese_name       0
# generation          0
# status              0
# species             0
# type_number         0
# type_1              0
# type_2              0
# height_m            0
# weight_kg           0
# abilities_number    0
# ability_1           0
# ability_2           0
# ability_hidden      0
# total_points        0
# hp                  0
# attack              0
# defense             0
# sp_attack           0
# sp_defense          0
# speed               0
# catch_rate          0
# base_friendship     0
# base_experience     0
# growth_rate         0
# egg_type_number     0
# egg_type_1          0
# percentage_male     0
# egg_cycles          0
# against_normal      0
# against_fire        0
# against_water       0
# against_electric    0
# against_grass       0
# against_ice         0
# against_fight       0
# against_poison      0
# against_ground      0
# against_flying      0
# against_psychic     0
# against_bug         0
# against_rock        0
# against_ghost       0
# against_dragon      0
# against_dark        0
# against_steel       0
# against_fairy       0
# dtype: int64

# %%
dataset.shape
# Out:
# (213, 50)

# %%
((1028-213)/1028)*100
# Out:
# 79.28015564202335

# %%
sns.heatmap(dataset.isnull())
plt.show()
