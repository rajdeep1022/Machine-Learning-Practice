# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("College_Admission.csv")
dataset.head(3)
# Out:
#    student_id  age  gender category          state preferred_stream  \
# 0      250.99   17   other  general         odisha       management
# 1      250.99   20   other      ews        gujarat      agriculture
# 2      250.99   19  female       sc  uttar pradesh         pharmacy
#
#   entrance_exam  entrance_score  board_percentage  extracurricular_score  \
# 0           cet              30             95.58                      2
# 1          none               0             75.45                      2
# 2           cet             120             75.36                     10
#
#    admission_probability admission_status scholarship_eligibility
# 0                  0.387         admitted                     yes
# 1                  0.221         rejected                      no
# 2                  0.446         rejected                      no

# %%
dataset.isnull().sum()
# Out:
# student_id                 0
# age                        0
# gender                     0
# category                   0
# state                      0
# preferred_stream           0
# entrance_exam              0
# entrance_score             0
# board_percentage           0
# extracurricular_score      0
# admission_probability      0
# admission_status           0
# scholarship_eligibility    0
# dtype: int64

# %%
sns.displot(dataset['entrance_score'],kde=True)
plt.show()

# %%
dataset.describe()
# Out:
#          student_id           age  entrance_score  board_percentage  \
# count  25000.000000  25000.000000    25000.000000      25000.000000
# mean   12500.500000     18.492440       77.879760         75.028014
# std     7212.732314      1.116205      120.356125         14.438767
# min      250.990000     17.000000        0.000000         50.440000
# 25%     6250.750000     17.000000        0.000000         62.550000
# 50%    12500.500000     18.000000       20.000000         75.070000
# 75%    18750.250000     19.000000      126.000000         87.640000
# max    24750.010000     20.000000      634.000000         99.530000
#
#        extracurricular_score  admission_probability
# count           25000.000000           25000.000000
# mean                4.990920               0.323997
# std                 3.158942               0.142427
# min                 0.000000               0.041990
# 25%                 2.000000               0.219000
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
dataset['entrance_score_ss'] = pd.DataFrame(ss.fit_transform(dataset[["entrance_score"]]))

# %%
dataset.head(3)
# Out:
#    student_id  age  gender category          state preferred_stream  \
# 0      250.99   17   other  general         odisha       management
# 1      250.99   20   other      ews        gujarat      agriculture
# 2      250.99   19  female       sc  uttar pradesh         pharmacy
#
#   entrance_exam  entrance_score  board_percentage  extracurricular_score  \
# 0           cet       -0.397825             95.58                      2
# 1          none       -0.647091             75.45                      2
# 2           cet        0.349970             75.36                     10
#
#    admission_probability admission_status scholarship_eligibility  \
# 0                  0.387         admitted                     yes
# 1                  0.221         rejected                      no
# 2                  0.446         rejected                      no
#
#    entrance_score ss  entrance_score_ss
# 0          -0.397825          -0.397825
# 1          -0.647091          -0.647091
# ...

# %%
dataset.describe()
# Out:
#          student_id           age  entrance_score  board_percentage  \
# count  25000.000000  25000.000000    2.500000e+04      25000.000000
# mean   12500.500000     18.492440   -1.605827e-17         75.028014
# std     7212.732314      1.116205    1.000020e+00         14.438767
# min      250.990000     17.000000   -6.470906e-01         50.440000
# 25%     6250.750000     17.000000   -6.470906e-01         62.550000
# 50%    12500.500000     18.000000   -4.809138e-01         75.070000
# 75%    18750.250000     19.000000    3.998235e-01         87.640000
# max    24750.010000     20.000000    4.620715e+00         99.530000
#
#        extracurricular_score  admission_probability  entrance_score ss  \
# count           25000.000000           25000.000000       2.500000e+04
# mean                4.990920               0.323997      -1.321609e-17
# std                 3.158942               0.142427       1.000020e+00
# ...

# %%
sns.displot(dataset['entrance_score_ss'],kde=True)
plt.show()
