# %%
import pandas as pd

# %%
data = {"name":["a","b","c","d","a","c"],"eng":[8,7,5,8,8,5],"hindi":[2,3,4,5,2,6]}

# %%
df= pd.DataFrame(data)
df
# Out:
#   name  eng  hindi
# 0    a    8      2
# 1    b    7      3
# 2    c    5      4
# 3    d    8      5
# 4    a    8      2
# 5    c    5      6

# %% [markdown]
# .duplicated() is a Pandas function used to identify duplicate rows in a DataFrame.

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
df.drop_duplicates(keep="first",inplace=True)
df
# Out:
#   name  eng  hindi
# 0    a    8      2
# 1    b    7      3
# 2    c    5      4
# 3    d    8      5
# 5    c    5      6

# %%
dataset = pd.read_csv("College_Admission.csv")
dataset.head(3)
# Out:
#    student_id  age  gender category          state preferred_stream  \
# 0      250.99   17   other  general         odisha       management
# 1      250.99   20   other      ews        gujarat      agriculture
# 2      250.99   19  female       sc  uttar pradesh         pharmacy
#
#   entrance_exam  entrance_score  board_percentage  extracurricular_score  \
# 0           cet              30             95.58                      2
# 1          none               0             75.45                      2
# 2           cet             120             75.36                     10
#
#    admission_probability admission_status scholarship_eligibility
# 0                  0.387         admitted                     yes
# 1                  0.221         rejected                      no
# 2                  0.446         rejected                      no

# %%
dataset.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 24995    False
# 24996    False
# 24997    False
# 24998    False
# 24999    False
# Length: 25000, dtype: bool

# %%
dataset.shape
# Out:
# (25000, 13)

# %%
dataset.drop_duplicates(keep="first",inplace=True)
dataset.shape
# Out:
# (25000, 13)
